# %% [markdown]
# ## Decision Analysis - Project 2

# %% [markdown]
# Authors:
# * Szudzik Oskar, 148245
# * Moras Krystian, 148243

# %%
import pandas as pd
df = pd.read_csv('apartments.csv',decimal=",")
df.iloc[[9]]
# Out:
#                                                 link  price  \
# 9  https://www.otodom.pl//pl/oferta/nowe-2-pokojo...   2350
#
#                              address  \
# 9  Poznań, Starołęka, ul. Wagrowska
#
#                                           directions  area  aesthetics  \
# 9  https://www.google.com/maps/dir/Centrum%20Wyk%...  41.0         8.0
#
#    commutation  gym_num
# 9           23        1

# %%
import numpy as np

df = pd.read_csv('apartments.csv',decimal=",")
df
# Out:
#                                                  link  price  \
# 0   https://www.otodom.pl//pl/oferta/2-niezalezne-...   2350
# 1   https://www.otodom.pl//pl/oferta/2pokojowe-ata...   2300
# 2   https://www.otodom.pl//pl/oferta/nowe-mieszkan...   2800
# 3   https://www.otodom.pl//pl/oferta/mieszkanie-2-...   1700
# 4   https://www.otodom.pl//pl/oferta/nowe-komforto...   2350
# 5   https://www.otodom.pl//pl/oferta/centrum-przy-...   2500
# 6   https://www.otodom.pl//pl/oferta/mieszkanie-la...   1900
# 7   https://www.otodom.pl//pl/oferta/luksusowy-apa...   8000
# 8   https://www.otodom.pl//pl/oferta/paryski-szyk-...   2500
# 9   https://www.otodom.pl//pl/oferta/nowe-2-pokojo...   2350
# 10  https://www.otodom.pl//pl/oferta/2-pokoje-podo...   2700
# 11  https://www.otodom.pl/pl/oferta/klimatyczne-mi...   2400
# 12  https://www.otodom.pl/pl/oferta/dwupokojowe-mi...   2500
# 13  https://www.otodom.pl/pl/oferta/mieszkanie-brz...   2800
#
#                                              address  \
# 0   Poznań, Piątkowo, ul. Zygmunta Wojciechowskiego
# 1        Poznań, Piątkowo, osiedle Stefana Batorego
# 2                      Poznań, Grunwald, ul. Ptasia
# 3                   Poznań, Naramowice, ul. Radłowa
# 4                           Podolany, Poznań, Poznań
# 5      Poznań, Centrum, ul. Franciszka Ratajczaka 21
# 6                   Poznań, Łazarz, ul. Głogowska 65
# 7        Poznań, Chwaliszewo, ul. Tylne Chwaliszewo
# 8                 Poznań, Górna Wilda, ul. Różana 21
# 9                  Poznań, Starołęka, ul. Wagrowska
# 10                  Poznań, Podolany, ul. Jasielska
# 11                           Poznań, Rzeczpospolitej
# 12                                  Poznań, Piątkowo
# 13                          Poznań, grunwald, brzask
#
#                                            directions  area  aesthetics  \
# 0   https://www.google.com/maps/dir/Centrum%20Wyk%...  40.0         7.0
# 1   https://www.google.com/maps/dir/Centrum%20Wyk%...  50.0         3.0
# 2   https://www.google.com/maps/dir/Centrum%20Wyk%...  49.0         6.0
# 3   https://www.google.com/maps/dir/Centrum%20Wyk%...  32.5         5.0
# 4   https://www.google.com/maps/dir/Centrum%20Wyk%...  43.0         7.5
# 5   https://www.google.com/maps/dir/Centrum%20Wyk%...  45.0         7.0
# 6   https://www.google.com/maps/dir/Centrum%20Wyk%...  48.0         2.0
# 7   https://www.google.com/maps/dir/Centrum%20Wyk%...  78.0        10.0
# 8   https://www.google.com/maps/dir/Centrum%20Wyk%...  54.0         6.0
# 9   https://www.google.com/maps/dir/Centrum%20Wyk%...  41.0         8.0
# 10  https://www.google.com/maps/dir/Centrum%20Wyk%...  50.0         6.0
# 11  https://www.google.com/maps/dir/Centrum+Wykład...  50.0         5.0
# 12  https://www.google.com/maps/dir/Centrum+Wyk%C5...  41.5         8.0
# 13  https://www.google.com/maps/dir/Centrum+Wykład...  59.0         9.0
#
#     commutation  gym_num
# 0            40        7
# 1            42        6
# 2            39        9
# 3            44        2
# 4            51        4
# 5            19        3
# 6            28        1
# 7            17        2
# 8            20        2
# 9            23        1
# 10           42       10
# 11           14        3
# 12           42        2
# 13           38        7

# %%
alternatives = df[["price","area","aesthetics","commutation","gym_num"]]
alternatives
# Out:
#     price  area  aesthetics  commutation  gym_num
# 0    2350  40.0         7.0           40        7
# 1    2300  50.0         3.0           42        6
# 2    2800  49.0         6.0           39        9
# 3    1700  32.5         5.0           44        2
# 4    2350  43.0         7.5           51        4
# 5    2500  45.0         7.0           19        3
# 6    1900  48.0         2.0           28        1
# 7    8000  78.0        10.0           17        2
# 8    2500  54.0         6.0           20        2
# 9    2350  41.0         8.0           23        1
# 10   2700  50.0         6.0           42       10
# 11   2400  50.0         5.0           14        3
# 12   2500  41.5         8.0           42        2
# 13   2800  59.0         9.0           38        7

# %%
def get_alternatives():
    df = pd.read_csv('apartments.csv',decimal=",")
    return df[["price","area","aesthetics","commutation","gym_num"]]

# %% [markdown]
# ## UTA

# %% [markdown]
# Get minimal $\alpha$ and maximal $\beta$ values for all criteria

# %%
alternatives = get_alternatives()

def get_min_values(alternatives):
    mins = alternatives.min()
    # if column is int change value to int
    mins_dict = {}
    for col in alternatives.columns:
        if alternatives[col].dtype == np.int64:
            mins_dict[col] = int(mins[col])
        else:
            mins_dict[col] = mins[col]
    return mins_dict

def get_max_values(alternatives):
    maxs = alternatives.max()
    # if column is int change value to int
    maxs_dict = {}
    for col in alternatives.columns:
        if alternatives[col].dtype == np.int64:
            maxs_dict[col] = int(maxs[col])
        else:
            maxs_dict[col] = maxs[col]

    return maxs_dict
get_min_values(alternatives), get_max_values(alternatives)
# Out:
# ({'price': 1700,
#   'area': 32.5,
#   'aesthetics': 2.0,
#   'commutation': 14,
#   'gym_num': 1},
#  {'price': 8000,
#   'area': 78.0,
#   'aesthetics': 10.0,
#   'commutation': 51,
#   'gym_num': 10})

# %%
import pulp

prob = pulp.LpProblem("UTA_Method_with_Binary_Inconsistency_Solver", pulp.LpMinimize)

def estimation_constraints(number_of_alternatives, problem):

    # each alternative has over and under estimation error variable
    over = pulp.LpVariable.dicts("over", range(number_of_alternatives))
    under = pulp.LpVariable.dicts("under", range(number_of_alternatives))

    # minimize the sum of over and under estimation error
    problem += pulp.lpSum([over[i] + under[i] for i in range(number_of_alternatives)])

    for i in range(number_of_alternatives):
        problem += over[i] >= 0
        problem += under[i] >= 0
    return problem

prob = estimation_constraints(len(alternatives), prob)
#prob

# %%
def criterion_values_variables(alternatives):

    # variable for each unique value of each criterion
    vars = dict()
    for criterion in alternatives.columns:
        unique_values = alternatives[criterion].unique()
        for value in unique_values:
            vars[criterion + "_" + str(value)] = pulp.LpVariable(criterion + "_" + str(value))

    return vars

vars = criterion_values_variables(alternatives)
vars
# Out:
# {'price_2350': price_2350,
#  'price_2300': price_2300,
#  'price_2800': price_2800,
#  'price_1700': price_1700,
#  'price_2500': price_2500,
#  'price_1900': price_1900,
#  'price_8000': price_8000,
#  'price_2700': price_2700,
#  'price_2400': price_2400,
#  'area_40.0': area_40.0,
#  'area_50.0': area_50.0,
#  'area_49.0': area_49.0,
#  'area_32.5': area_32.5,
#  'area_43.0': area_43.0,
#  'area_45.0': area_45.0,
#  'area_48.0': area_48.0,
#  'area_78.0': area_78.0,
#  'area_54.0': area_54.0,
#  'area_41.0': area_41.0,
#  'area_41.5': area_41.5,
#  'area_59.0': area_59.0,
#  'aesthetics_7.0': aesthetics_7.0,
#  'aesthetics_3.0': aesthetics_3.0,
#  'aesthetics_6.0': aesthetics_6.0,
#  'aesthetics_5.0': aesthetics_5.0,
#  'aesthetics_7.5': aesthetics_7.5,
#  'aesthetics_2.0': aesthetics_2.0,
#  'aesthetics_10.0': aesthetics_10.0,
#  'aesthetics_8.0': aesthetics_8.0,
#  'aesthetics_9.0': aesthetics_9.0,
#  'commutation_40': commutation_40,
#  'commutation_42': commutation_42,
#  'commutation_39': commutation_39,
#  'commutation_44': commutation_44,
#  'commutation_51': commutation_51,
#  'commutation_19': commutation_19,
#  'commutation_28': commutation_28,
#  'commutation_17': commutation_17,
#  'commutation_20': commutation_20,
#  'commutation_23': commutation_23,
#  'commutation_14': commutation_14,
#  'commutation_38': commutation_38,
#  'gym_num_7': gym_num_7,
#  'gym_num_6': gym_num_6,
#  'gym_num_9': gym_num_9,
#  'gym_num_2': gym_num_2,
#  'gym_num_4': gym_num_4,
#  'gym_num_3': gym_num_3,
#  'gym_num_1': gym_num_1,
#  'gym_num_10': gym_num_10}

# %%
def criterion_values_constraints(alternatives, vars, problem, gains):
    # nonnegativity constraints
    for var in vars.values():
        problem += var >= 0

    # get maximum and minimum values of each criterion
    min_values = get_min_values(alternatives)
    max_values = get_max_values(alternatives)
    
    # each criterion for min value is 0
    for criterion in alternatives.columns:
        problem += vars[criterion + "_" + str( min_values[criterion])] == 0
    
    # sum of max value criteria is 1
    
    problem += pulp.lpSum([vars[criterion + "_" + str(max_values[criterion])] for criterion in alternatives.columns]) == 1

    # monotonicity constraints
    for criterion in alternatives.columns:
        vals = alternatives[criterion].unique()
        # sort values in ascending order
        vals.sort()
        # if gain then values should be increasing
        if gains[criterion]:
            for i in range(len(vals) - 1):
                problem += vars[criterion + "_" + str(vals[i])] <= vars[criterion + "_" + str(vals[i + 1])]
        # if gain is false then values should be decreasing
        else:
            for i in range(len(vals) - 1):
                problem += vars[criterion + "_" + str(vals[i])] >= vars[criterion + "_" + str(vals[i + 1])]

    return problem

gains = {"price": False, "area": True, "aesthetics": True, "commutation": False, "gym_num": True}

prob = criterion_values_constraints(alternatives, vars, prob, gains)

# %%
prob
# Out:
# UTA_Method_with_Binary_Inconsistency_Solver:
# MINIMIZE
# 1*over_0 + 1*over_1 + 1*over_10 + 1*over_11 + 1*over_12 + 1*over_13 + 1*over_2 + 1*over_3 + 1*over_4 + 1*over_5 + 1*over_6 + 1*over_7 + 1*over_8 + 1*over_9 + 1*under_0 + 1*under_1 + 1*under_10 + 1*under_11 + 1*under_12 + 1*under_13 + 1*under_2 + 1*under_3 + 1*under_4 + 1*under_5 + 1*under_6 + 1*under_7 + 1*under_8 + 1*under_9 + 0
# SUBJECT TO
# _C1: over_0 >= 0
#
# _C2: under_0 >= 0
#
# _C3: over_1 >= 0
#
# _C4: under_1 >= 0
#
# _C5: over_2 >= 0
#
# _C6: under_2 >= 0
#
# _C7: over_3 >= 0
#
# _C8: under_3 >= 0
#
# _C9: over_4 >= 0
#
# _C10: under_4 >= 0
#
# _C11: over_5 >= 0
#
# _C12: under_5 >= 0
#
# _C13: over_6 >= 0
#
# _C14: under_6 >= 0
#
# _C15: over_7 >= 0
#
# _C16: under_7 >= 0
#
# _C17: over_8 >= 0
#
# _C18: under_8 >= 0
#
# _C19: over_9 >= 0
#
# _C20: under_9 >= 0
#
# _C21: over_10 >= 0
#
# _C22: under_10 >= 0
#
# _C23: over_11 >= 0
#
# _C24: under_11 >= 0
#
# _C25: over_12 >= 0
#
# _C26: under_12 >= 0
#
# _C27: over_13 >= 0
#
# _C28: under_13 >= 0
#
# _C29: price_2350 >= 0
#
# _C30: price_2300 >= 0
#
# _C31: price_2800 >= 0
#
# _C32: price_1700 >= 0
#
# _C33: price_2500 >= 0
#
# _C34: price_1900 >= 0
#
# _C35: price_8000 >= 0
#
# _C36: price_2700 >= 0
#
# _C37: price_2400 >= 0
#
# _C38: area_40.0 >= 0
#
# _C39: area_50.0 >= 0
#
# _C40: area_49.0 >= 0
#
# _C41: area_32.5 >= 0
#
# _C42: area_43.0 >= 0
#
# _C43: area_45.0 >= 0
#
# _C44: area_48.0 >= 0
#
# _C45: area_78.0 >= 0
#
# _C46: area_54.0 >= 0
#
# _C47: area_41.0 >= 0
#
# _C48: area_41.5 >= 0
#
# _C49: area_59.0 >= 0
#
# _C50: aesthetics_7.0 >= 0
#
# _C51: aesthetics_3.0 >= 0
#
# _C52: aesthetics_6.0 >= 0
#
# _C53: aesthetics_5.0 >= 0
#
# _C54: aesthetics_7.5 >= 0
#
# _C55: aesthetics_2.0 >= 0
#
# _C56: aesthetics_10.0 >= 0
#
# _C57: aesthetics_8.0 >= 0
#
# _C58: aesthetics_9.0 >= 0
#
# _C59: commutation_40 >= 0
#
# _C60: commutation_42 >= 0
#
# _C61: commutation_39 >= 0
#
# _C62: commutation_44 >= 0
#
# _C63: commutation_51 >= 0
#
# _C64: commutation_19 >= 0
#
# _C65: commutation_28 >= 0
#
# _C66: commutation_17 >= 0
#
# _C67: commutation_20 >= 0
#
# _C68: commutation_23 >= 0
#
# _C69: commutation_14 >= 0
#
# _C70: commutation_38 >= 0
#
# _C71: gym_num_7 >= 0
#
# _C72: gym_num_6 >= 0
#
# _C73: gym_num_9 >= 0
#
# _C74: gym_num_2 >= 0
#
# _C75: gym_num_4 >= 0
#
# _C76: gym_num_3 >= 0
#
# _C77: gym_num_1 >= 0
#
# _C78: gym_num_10 >= 0
#
# _C79: price_1700 = 0
#
# _C80: area_32.5 = 0
#
# _C81: aesthetics_2.0 = 0
#
# _C82: commutation_14 = 0
#
# _C83: gym_num_1 = 0
#
# _C84: aesthetics_10.0 + area_78.0 + commutation_51 + gym_num_10 + price_8000
#  = 1
#
# _C85: price_1700 - price_1900 >= 0
#
# _C86: price_1900 - price_2300 >= 0
#
# _C87: price_2300 - price_2350 >= 0
#
# _C88: price_2350 - price_2400 >= 0
#
# _C89: price_2400 - price_2500 >= 0
#
# _C90: price_2500 - price_2700 >= 0
#
# _C91: price_2700 - price_2800 >= 0
#
# _C92: price_2800 - price_8000 >= 0
#
# _C93: area_32.5 - area_40.0 <= 0
#
# _C94: area_40.0 - area_41.0 <= 0
#
# _C95: area_41.0 - area_41.5 <= 0
#
# _C96: area_41.5 - area_43.0 <= 0
#
# _C97: area_43.0 - area_45.0 <= 0
#
# _C98: area_45.0 - area_48.0 <= 0
#
# _C99: area_48.0 - area_49.0 <= 0
#
# _C100: area_49.0 - area_50.0 <= 0
#
# _C101: area_50.0 - area_54.0 <= 0
#
# _C102: area_54.0 - area_59.0 <= 0
#
# _C103: area_59.0 - area_78.0 <= 0
#
# _C104: aesthetics_2.0 - aesthetics_3.0 <= 0
#
# _C105: aesthetics_3.0 - aesthetics_5.0 <= 0
#
# _C106: aesthetics_5.0 - aesthetics_6.0 <= 0
#
# _C107: aesthetics_6.0 - aesthetics_7.0 <= 0
#
# _C108: aesthetics_7.0 - aesthetics_7.5 <= 0
#
# _C109: aesthetics_7.5 - aesthetics_8.0 <= 0
#
# _C110: aesthetics_8.0 - aesthetics_9.0 <= 0
#
# _C111: - aesthetics_10.0 + aesthetics_9.0 <= 0
#
# _C112: commutation_14 - commutation_17 >= 0
#
# _C113: commutation_17 - commutation_19 >= 0
#
# _C114: commutation_19 - commutation_20 >= 0
#
# _C115: commutation_20 - commutation_23 >= 0
#
# _C116: commutation_23 - commutation_28 >= 0
#
# _C117: commutation_28 - commutation_38 >= 0
#
# _C118: commutation_38 - commutation_39 >= 0
#
# _C119: commutation_39 - commutation_40 >= 0
#
# _C120: commutation_40 - commutation_42 >= 0
#
# _C121: commutation_42 - commutation_44 >= 0
#
# _C122: commutation_44 - commutation_51 >= 0
#
# _C123: gym_num_1 - gym_num_2 <= 0
#
# _C124: gym_num_2 - gym_num_3 <= 0
#
# _C125: gym_num_3 - gym_num_4 <= 0
#
# _C126: gym_num_4 - gym_num_6 <= 0
#
# _C127: gym_num_6 - gym_num_7 <= 0
#
# _C128: gym_num_7 - gym_num_9 <= 0
#
# _C129: - gym_num_10 + gym_num_9 <= 0
#
# VARIABLES
# aesthetics_10.0 free Continuous
# aesthetics_2.0 free Continuous
# aesthetics_3.0 free Continuous
# aesthetics_5.0 free Continuous
# aesthetics_6.0 free Continuous
# aesthetics_7.0 free Continuous
# aesthetics_7.5 free Continuous
# aesthetics_8.0 free Continuous
# aesthetics_9.0 free Continuous
# area_32.5 free Continuous
# area_40.0 free Continuous
# area_41.0 free Continuous
# area_41.5 free Continuous
# area_43.0 free Continuous
# area_45.0 free Continuous
# area_48.0 free Continuous
# area_49.0 free Continuous
# area_50.0 free Continuous
# area_54.0 free Continuous
# area_59.0 free Continuous
# area_78.0 free Continuous
# commutation_14 free Continuous
# commutation_17 free Continuous
# commutation_19 free Continuous
# commutation_20 free Continuous
# commutation_23 free Continuous
# commutation_28 free Continuous
# commutation_38 free Continuous
# commutation_39 free Continuous
# commutation_40 free Continuous
# commutation_42 free Continuous
# commutation_44 free Continuous
# commutation_51 free Continuous
# gym_num_1 free Continuous
# gym_num_10 free Continuous
# gym_num_2 free Continuous
# gym_num_3 free Continuous
# gym_num_4 free Continuous
# gym_num_6 free Continuous
# gym_num_7 free Continuous
# gym_num_9 free Continuous
# over_0 free Continuous
# over_1 free Continuous
# over_10 free Continuous
# over_11 free Continuous
# over_12 free Continuous
# over_13 free Continuous
# over_2 free Continuous
# over_3 free Continuous
# over_4 free Continuous
# over_5 free Continuous
# over_6 free Continuous
# over_7 free Continuous
# over_8 free Continuous
# over_9 free Continuous
# price_1700 free Continuous
# price_1900 free Continuous
# price_2300 free Continuous
# price_2350 free Continuous
# price_2400 free Continuous
# price_2500 free Continuous
# price_2700 free Continuous
# price_2800 free Continuous
# price_8000 free Continuous
# under_0 free Continuous
# under_1 free Continuous
# under_10 free Continuous
# under_11 free Continuous
# under_12 free Continuous
# under_13 free Continuous
# under_2 free Continuous
# under_3 free Continuous
# under_4 free Continuous
# under_5 free Continuous
# under_6 free Continuous
# under_7 free Continuous
# under_8 free Continuous
# under_9 free Continuous

# %%
ranking = [9,12,13,3,11,0,4,5,2,8,10,7,1,6]

# %%
for i in range(len(ranking)-1):
    j = i + 1
    left_side = [vars[criterion + "_" + str(alternatives[criterion][ranking[i]])] for criterion in alternatives.columns]
    left_side.extend([prob.variablesDict()["over_" + str(ranking[j])], prob.variablesDict()["under_" + str(ranking[i])]])
    right_side = [vars[criterion + "_" + str(alternatives[criterion][ranking[j]])] for criterion in alternatives.columns]
    right_side.extend([prob.variablesDict()["over_" + str(ranking[j])], prob.variablesDict()["under_" + str(ranking[j])]])
    
    equation = pulp.lpSum(left_side) >= pulp.lpSum(right_side) + 0.01
    print(equation)
    prob += equation
# Out:
# 0*aesthetics_8.0 + area_41.0 - area_41.5 + commutation_23 - commutation_42 + gym_num_1 - gym_num_2 + 0*over_12 + price_2350 - price_2500 - under_12 + under_9 >= 0.01
# aesthetics_8.0 - aesthetics_9.0 + area_41.5 - area_59.0 - commutation_38 + commutation_42 + gym_num_2 - gym_num_7 + 0*over_13 + price_2500 - price_2800 + under_12 - under_13 >= 0.01
# -aesthetics_5.0 + aesthetics_9.0 - area_32.5 + area_59.0 + commutation_38 - commutation_44 - gym_num_2 + gym_num_7 + 0*over_3 - price_1700 + price_2800 + under_13 - under_3 >= 0.01
# 0*aesthetics_5.0 + area_32.5 - area_50.0 - commutation_14 + commutation_44 + gym_num_2 - gym_num_3 + 0*over_11 + price_1700 - price_2400 - under_11 + under_3 >= 0.01
# aesthetics_5.0 - aesthetics_7.0 - area_40.0 + area_50.0 + commutation_14 - commutation_40 + gym_num_3 - gym_num_7 + 0*over_0 - price_2350 + price_2400 - under_0 + under_11 >= 0.01
# aesthetics_7.0 - aesthetics_7.5 + area_40.0 - area_43.0 + commutation_40 - commutation_51 - gym_num_4 + gym_num_7 + 0*over_4 + 0*price_2350 + under_0 - under_4 >= 0.01
# -aesthetics_7.0 + aesthetics_7.5 + area_43.0 - area_45.0 - commutation_19 + commutation_51 - gym_num_3 + gym_num_4 + 0*over_5 + price_2350 - price_2500 + under_4 - under_5 >= 0.01
# -aesthetics_6.0 + aesthetics_7.0 + area_45.0 - area_49.0 + commutation_19 - commutation_39 + gym_num_3 - gym_num_9 + 0*over_2 + price_2500 - price_2800 - under_2 + under_5 >= 0.01
# 0*aesthetics_6.0 + area_49.0 - area_54.0 - commutation_20 + commutation_39 - gym_num_2 + gym_num_9 + 0*over_8 - price_2500 + price_2800 + under_2 - under_8 >= 0.01
# 0*aesthetics_6.0 - area_50.0 + area_54.0 + commutation_20 - commutation_42 - gym_num_10 + gym_num_2 + 0*over_10 + price_2500 - price_2700 - under_10 + under_8 >= 0.01
# -aesthetics_10.0 + aesthetics_6.0 + area_50.0 - area_78.0 - commutation_17 + commutation_42 + gym_num_10 - gym_num_2 + 0*over_7 + price_2700 - price_8000 + under_10 - under_7 >= 0.01
# aesthetics_10.0 - aesthetics_3.0 - area_50.0 + area_78.0 + commutation_17 - commutation_42 + gym_num_2 - gym_num_6 + 0*over_1 - price_2300 + price_8000 - under_1 + under_7 >= 0.01
# -aesthetics_2.0 + aesthetics_3.0 - area_48.0 + area_50.0 - commutation_28 + commutation_42 - gym_num_1 + gym_num_6 + 0*over_6 - price_1900 + price_2300 + under_1 - under_6 >= 0.01

# %%
prob.solve()
# Out:
# 1

# %%
# print the status of the solved LP
print("Status:", pulp.LpStatus[prob.status])

# print the value of the variables at the optimum
for v in prob.variables():
    print(v.name, "=", v.varValue)

# print the value of the objective
print(pulp.value(prob.objective))
# Out:
# Status: Optimal
# aesthetics_10.0 = 0.95
# aesthetics_2.0 = 0.0
# aesthetics_3.0 = 0.0
# aesthetics_5.0 = 0.91
# aesthetics_6.0 = 0.91
# aesthetics_7.0 = 0.94
# aesthetics_7.5 = 0.95
# aesthetics_8.0 = 0.95
# aesthetics_9.0 = 0.95
# area_32.5 = 0.0
# area_40.0 = 0.0
# area_41.0 = 0.0
# area_41.5 = 0.0
# area_43.0 = 0.0
# area_45.0 = 0.0
# area_48.0 = 0.0
# area_49.0 = 0.0
# area_50.0 = 0.0
# area_54.0 = 0.0
# area_59.0 = 0.0
# area_78.0 = 0.0
# commutation_14 = 0.0
# commutation_17 = 0.0
# commutation_19 = 0.0
# commutation_20 = 0.0
# commutation_23 = 0.0
# commutation_28 = 0.0
# commutation_38 = 0.0
# commutation_39 = 0.0
# commutation_40 = 0.0
# commutation_42 = 0.0
# commutation_44 = 0.0
# commutation_51 = 0.0
# gym_num_1 = 0.0
# gym_num_10 = 0.05
# gym_num_2 = 0.0
# gym_num_3 = 0.05
# gym_num_4 = 0.05
# gym_num_6 = 0.05
# gym_num_7 = 0.05
# gym_num_9 = 0.05
# over_0 = 0.0
# over_1 = 0.0
# over_10 = 0.0
# over_11 = 0.0
# over_12 = 0.0
# over_13 = 0.0
# over_2 = 0.0
# over_3 = 0.0
# over_4 = 0.0
# over_5 = 0.0
# over_6 = 0.0
# over_7 = 0.0
# over_8 = 0.0
# over_9 = 0.0
# price_1700 = 0.0
# price_1900 = 0.0
# price_2300 = 0.0
# price_2350 = 0.0
# price_2400 = 0.0
# price_2500 = 0.0
# price_2700 = 0.0
# price_2800 = 0.0
# price_8000 = 0.0
# under_0 = 0.02
# under_1 = 0.0
# under_10 = 0.0
# under_11 = 0.06
# under_12 = 0.1
# under_13 = 0.04
# under_2 = 0.02
# under_3 = 0.12
# under_4 = 0.0
# under_5 = 0.0
# under_6 = 0.0
# under_7 = 0.0
# under_8 = 0.06
# under_9 = 0.11
# 0.53

# %%
# plot marginal values of criteria
import matplotlib.pyplot as plt
import numpy as np

def plot_marginal_values(vars):
    # get unique values of each criterion
    unique_values = dict()
    for criterion in alternatives.columns:
        unique_values[criterion] = alternatives[criterion].unique()
        unique_values[criterion].sort()

    # get marginal values of each criterion
    marginal_values = dict()
    for criterion in alternatives.columns:
        marginal_values[criterion] = [vars[criterion + "_" + str(value)].varValue for value in unique_values[criterion]]

    # plot marginal values
    # subplots for each criterion
    fig, axs = plt.subplots(len(alternatives.columns), 1, figsize=(10, 10))
    for i, criterion in enumerate(alternatives.columns):
        axs[i].plot(unique_values[criterion], marginal_values[criterion])
        # increase margin between plots
        plt.subplots_adjust(hspace=0.5)
        axs[i].set_xlabel(criterion)
        axs[i].set_ylabel("Marginal Value")
        axs[i].grid()
    plt.show()
        

plot_marginal_values(prob.variablesDict())

# %%
# calculate ranking based on the values of the variables



def calculate_ranking(alternatives, vars):

    values = dict()

    for i in range(len(alternatives)):
        values[i] = 0

        for c in alternatives.columns:
            values[i] += vars[c + "_" + str(alternatives[c][i])].varValue
    print(values)
    return sorted(values, key=values.get, reverse=True)

ranking_2 = calculate_ranking(alternatives, prob.variablesDict())
print(ranking,ranking_2)
# Out:
# {0: 0.99, 1: 0.05, 2: 0.9600000000000001, 3: 0.91, 4: 1.0, 5: 0.99, 6: 0.0, 7: 0.95, 8: 0.91, 9: 0.95, 10: 0.9600000000000001, 11: 0.9600000000000001, 12: 0.95, 13: 1.0}
# [9, 12, 13, 3, 11, 0, 4, 5, 2, 8, 10, 7, 1, 6] [4, 13, 0, 5, 2, 10, 11, 7, 9, 12, 3, 8, 1, 6]

# %%
consistency = pulp.LpVariable.dicts("Consistency", ((i, j) for i in data_norm.index for j in data_norm.columns), 0, 1, pulp.LpBinary)

prob = pulp.LpProblem("UTA", pulp.LpMaximize)

prob += pulp.lpSum([consistency[(i, j)] for i in data_norm.index for j in data_norm.columns])

# Add the consistency constraints
for i in data_norm.index:
    for j in data_norm.columns:
        if j == 'aesthetics':
            prob += consistency[(i, j)] == (data_norm.loc[i, j] >= aesthetics_threshold)
        elif j == 'commutation':
            prob += consistency[(i, j)] == (data_norm.loc[i, j] >= commutation_threshold)
        elif j == 'gym_num':
            prob += consistency[(i, j)] == (data_norm.loc[i, j] >= gym_num_threshold)
        else:
            prob += consistency[(i, j)] == 1

# Add the UTA weights constraints
prob += pulp.lpSum([weights[0]*data_norm.loc[i, 'price']*consistency[(i, 'price')] + 
               weights[1]*data_norm.loc[i, 'area']*consistency[(i, 'area')] +
               weights[2]*data_norm.loc[i, 'aesthetics']*consistency[(i, 'aesthetics')] +
               weights[3]*data_norm.loc[i, 'commutation']*consistency[(i, 'commutation')] + weights[4]*data_norm.loc[i, 'gym_num']*consistency[(i, 'gym_num')]
               for i in data_norm.index]) == 1

# %%
prob.solve()

print("Status:", pulp.LpStatus[prob.status])

if pulp.LpStatus[prob.status] == "Optimal":
    print("Solution:")
    for i in data_norm.index:
        print(f"Property {i+1}: {alternatives.loc[i, 'price']} (Price) + {alternatives.loc[i, 'area']} (Area) + {alternatives.loc[i, 'aesthetics']} (Aesthetics) + {alternatives.loc[i, 'commutation']} (Commutation) + {alternatives.loc[i, 'gym_num']} (Gym Num) = {pulp.value(prob.objective)}")
else:
    print("No optimal solution found.")
# Out:
# Status: Infeasible
# No optimal solution found.
